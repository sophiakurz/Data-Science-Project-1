# %% [markdown]
# ![Studiousness.jpg](attachment:Studiousness.jpg)

# %% [markdown]
# Once I collected data from a sufficient amount of studnets (a little over 100), I divided the data by the persons sign and how many hours they self-reported studying for. I then calculated the total sum of time that each sign studied (blue) and the average time each sign studied per week (orange).
#
# It's a little difficult to tell, but Virgo does, in fact, win for being the highest studing average, with 23.6 hours a week.

# %% [markdown]
# ![CNS.jpg](attachment:CNS.jpg)

# %% [markdown]
# ![Cockrell.jpg](attachment:Cockrell.jpg)

# %% [markdown]
# ![Mccombs.jpg](attachment:Mccombs.jpg)

# %% [markdown]
# I divided the data by the persons college and if they believed in astrology. I then sorted their answers, took count, and then created pie charts reflecting the data. As predicted, STEM and McCombs students were, primarily, more unbelieving.

# %% [markdown]
# ![Cola.jpg](attachment:Cola.jpg)

# %% [markdown]
# Contrastly, when examining students in COLA and their believability in astrology, they believed in astrology far more than students in the afore mentioned schools.

# %% [markdown]
# Based on the data I collected, I can confidently say that my hypothesis were proven correct.
